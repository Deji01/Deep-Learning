# %% [markdown]
# <a href="https://colab.research.google.com/github/Deji01/Deep-Learning/blob/main/Object_Detection_Supervision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --quiet supervision ultralytics

# %%
import cv2
from IPython import display
import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image
import supervision as sv
from supervision import VideoInfo
from ultralytics import YOLO

# %%
HOME = os.getcwd()
VIDEO_PATH = f"{HOME}/drive/MyDrive/Object-Detection-101/Videos/cars.mp4"
video_info = VideoInfo.from_video_path(VIDEO_PATH)

# %%
# extract video frame
generator = sv.get_video_frames_generator(VIDEO_PATH)
iterator = iter(generator)

frame = next(iterator)

# save frame
cv2.imwrite("frame_one.png", frame)
# Out:
# True

# %% [markdown]
# ### Alternative Method for Saving image
#
# ```python
# # resize the image to a width of 1280 and a height of 720
# resized_image = Image.fromarray(frame).resize((1280, 720))
#
# # save the image to a PNG file
# resized_image.save('resized_image.png')
# ```

# %%
polygons = [np.array([[20, 614],[488, 218],[652, 214],[692, 674]])]

# %%
model = YOLO("yolov8n.pt")
colors = sv.ColorPalette.default()

# %%
# initialize zones

zones = [
    sv.PolygonZone(
    polygon=polygon,
    frame_resolution_wh=video_info.resolution_wh
    ) for polygon in polygons
    ]

zone_annotators = [
    sv.PolygonZoneAnnotator(
        zone=zone,
        color=colors.by_idx(index),
        thickness=4,
        text_thickness=8,
        text_scale=4
    ) for index, zone in enumerate(zones)
]

box_annotators = [
    sv.BoxAnnotator(
        color=colors.by_idx(index),
        thickness=4,
        text_thickness=4,
        text_scale=2
    ) for index in range(len(polygons))
]

# %%
def process_frame(frame: np.ndarray, i) -> np.ndarray:
  results = model(frame, imgsz=1280)[0]
  detections = sv.Detections.from_yolov8(results)

  for zone, zone_annotator, box_annotator in zip(zones, zone_annotators, box_annotators):
    mask = zone.trigger(detections=detections)
    detections_filtered = detections[mask]
    frame = box_annotator.annotate(scene=frame, detections=detections_filtered, skip_label=True)
    frame = zone_annotator.annotate(scene=frame)

  return frame

# %%
display.clear_output()

# %%
results = model(frame, imgsz=1280)[0]
detections = sv.Detections.from_yolov8(results)

for zone, zone_annotator, box_annotator in zip(zones, zone_annotators, box_annotators):
    mask = zone.trigger(detections=detections)
    detections_filtered = detections[mask]
    frame = box_annotator.annotate(scene=frame, detections=detections_filtered)
    frame = zone_annotator.annotate(scene=frame)


sv.show_frame_in_notebook(frame, (16, 16))
# Out:
# 0: 736x1280 12 cars, 1 truck, 3 traffic lights, 17.2ms
# Speed: 1.3ms preprocess, 17.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)

# %%
sv.process_video(source_path=VIDEO_PATH,target_path="result.mp4", callback=process_frame)
# Out:
# 0: 736x1280 15 cars, 2 trucks, 3 traffic lights, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 2 trucks, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 2 trucks, 2 traffic lights, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 2 trucks, 1 traffic light, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 15 cars, 2 trucks, 1 traffic light, 20.6ms
# Speed: 1.2ms preprocess, 20.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 truck, 2 traffic lights, 20.9ms
# Speed: 1.2ms preprocess, 20.9ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 2 trucks, 2 traffic lights, 16.6ms
# Speed: 1.1ms preprocess, 16.6ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 2 traffic lights, 16.3ms
# Speed: 1.1ms preprocess, 16.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 1 traffic light, 19.4ms
# Speed: 3.1ms preprocess, 19.4ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 21 cars, 1 truck, 1 traffic light, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 1 traffic light, 15.2ms
# Speed: 2.2ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 33.5ms
# Speed: 1.0ms preprocess, 33.5ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 2 traffic lights, 19.7ms
# Speed: 2.8ms preprocess, 19.7ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 truck, 2 traffic lights, 16.2ms
# Speed: 1.1ms preprocess, 16.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 19 cars, 1 truck, 2 traffic lights, 18.0ms
# Speed: 1.2ms preprocess, 18.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 18 cars, 1 truck, 2 traffic lights, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 truck, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 truck, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 21 cars, 3 trucks, 2 traffic lights, 14.0ms
# Speed: 1.2ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 2 persons, 19 cars, 1 motorcycle, 1 truck, 2 traffic lights, 14.1ms
# Speed: 1.1ms preprocess, 14.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 19 cars, 1 bus, 1 truck, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 16 cars, 2 trucks, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 14.1ms
# Speed: 1.1ms preprocess, 14.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 2 trucks, 1 traffic light, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 bus, 2 trucks, 1 traffic light, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 2 trucks, 2 traffic lights, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 2 trucks, 2 traffic lights, 14.0ms
# Speed: 1.2ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 16 cars, 1 bus, 2 trucks, 2 traffic lights, 14.0ms
# Speed: 1.8ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 bus, 1 truck, 1 traffic light, 15.1ms
# Speed: 1.1ms preprocess, 15.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 1 truck, 1 traffic light, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 truck, 1 traffic light, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 14.1ms
# Speed: 1.2ms preprocess, 14.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 traffic light, 15.9ms
# Speed: 1.1ms preprocess, 15.9ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 1 traffic light, 20.7ms
# Speed: 1.1ms preprocess, 20.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 truck, 1 traffic light, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 1 traffic light, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 truck, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 truck, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 15.4ms
# Speed: 1.2ms preprocess, 15.4ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 14.1ms
# Speed: 5.4ms preprocess, 14.1ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 airplane, 1 truck, 1 traffic light, 14.0ms
# Speed: 1.2ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 14.0ms
# Speed: 1.2ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 airplane, 1 truck, 1 traffic light, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 2 trucks, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 truck, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 truck, 1 traffic light, 1 stop sign, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 2 trucks, 1 traffic light, 1 stop sign, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 truck, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 truck, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 truck, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 traffic light, 13.8ms
# Speed: 1.2ms preprocess, 13.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 2 traffic lights, 13.6ms
# Speed: 1.1ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 1 traffic light, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 14.6ms
# Speed: 1.1ms preprocess, 14.6ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 2 traffic lights, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 airplane, 1 truck, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 2 trucks, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 truck, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 24 cars, 2 trucks, 1 traffic light, 17.0ms
# Speed: 1.1ms preprocess, 17.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 21 cars, 1 bus, 1 truck, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 2 trucks, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 1 truck, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 2 trucks, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 2 trucks, 1 stop sign, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 1 stop sign, 13.7ms
# Speed: 1.1ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 1 stop sign, 15.7ms
# Speed: 1.0ms preprocess, 15.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 truck, 1 stop sign, 14.4ms
# Speed: 1.0ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 1 traffic light, 1 stop sign, 12.8ms
# Speed: 1.8ms preprocess, 12.8ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 21 cars, 1 truck, 1 stop sign, 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 truck, 1 stop sign, 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 22 cars, 1 truck, 1 stop sign, 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 1 stop sign, 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 1 stop sign, 19.3ms
# Speed: 1.0ms preprocess, 19.3ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 16.6ms
# Speed: 1.0ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 traffic light, 14.3ms
# Speed: 1.0ms preprocess, 14.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 1 traffic light, 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 21 cars, 1 traffic light, 14.5ms
# Speed: 1.4ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 22 cars, 1 traffic light, 13.7ms
# Speed: 1.1ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 2 trucks, 1 traffic light, 12.8ms
# Speed: 1.3ms preprocess, 12.8ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 21 cars, 2 trucks, 2 traffic lights, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 2 trucks, 2 traffic lights, 12.9ms
# Speed: 1.3ms preprocess, 12.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 2 trucks, 1 traffic light, 1 mouse, 13.7ms
# Speed: 1.1ms preprocess, 13.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 21 cars, 2 trucks, 1 traffic light, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 21 cars, 2 trucks, 1 traffic light, 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 2 trucks, 1 traffic light, 14.4ms
# Speed: 1.0ms preprocess, 14.4ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 2 trucks, 1 traffic light, 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 2 trucks, 2 traffic lights, 17.2ms
# Speed: 1.0ms preprocess, 17.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 1 truck, 2 traffic lights, 12.8ms
# Speed: 1.1ms preprocess, 12.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 truck, 1 traffic light, 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 21 cars, 1 bus, 1 truck, 1 traffic light, 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 bus, 1 truck, 1 traffic light, 17.2ms
# Speed: 1.0ms preprocess, 17.2ms inference, 2.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 bus, 1 truck, 1 traffic light, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 1 bus, 1 truck, 1 traffic light, 15.1ms
# Speed: 1.3ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 bus, 1 truck, 1 traffic light, 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 bus, 1 truck, 1 traffic light, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 22 cars, 1 bus, 1 truck, 1 traffic light, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 22 cars, 1 bus, 1 traffic light, 13.3ms
# Speed: 1.0ms preprocess, 13.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 1 bus, 1 traffic light, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 21 cars, 1 bus, 1 traffic light, 13.3ms
# Speed: 1.1ms preprocess, 13.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 1 bus, 1 traffic light, 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 bus, 1 truck, 1 traffic light, 12.8ms
# Speed: 1.0ms preprocess, 12.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 21 cars, 1 bus, 1 truck, 1 traffic light, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 21 cars, 1 bus, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 bus, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 bus, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.2ms preprocess, 13.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 21 cars, 1 bus, 1 traffic light, 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 bus, 2 trucks, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 bus, 1 truck, 1 traffic light, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 bus, 2 trucks, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 bus, 2 trucks, 1 traffic light, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 2 buss, 2 trucks, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 bus, 1 truck, 1 traffic light, 14.7ms
# Speed: 1.5ms preprocess, 14.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 bus, 2 trucks, 1 traffic light, 13.9ms
# Speed: 1.3ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 bus, 1 truck, 1 traffic light, 14.4ms
# Speed: 1.7ms preprocess, 14.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 bus, 1 truck, 1 traffic light, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 2 buss, 2 trucks, 1 traffic light, 16.9ms
# Speed: 1.1ms preprocess, 16.9ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 bus, 1 traffic light, 14.0ms
# Speed: 1.3ms preprocess, 14.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 bus, 1 truck, 1 traffic light, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 21 cars, 1 bus, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 bus, 1 traffic light, 20.7ms
# Speed: 1.0ms preprocess, 20.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 bus, 2 trucks, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 bus, 1 traffic light, 23.4ms
# Speed: 1.0ms preprocess, 23.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 bus, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 bus, 1 traffic light, 17.7ms
# Speed: 0.9ms preprocess, 17.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 bus, 1 traffic light, 14.0ms
# Speed: 3.9ms preprocess, 14.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 bus, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 bus, 1 truck, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 bus, 1 traffic light, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 bus, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 bus, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 16 cars, 1 bus, 1 truck, 1 traffic light, 15.9ms
# Speed: 1.0ms preprocess, 15.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 bus, 2 trucks, 1 traffic light, 14.0ms
# Speed: 0.9ms preprocess, 14.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 bus, 3 trucks, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 bus, 2 trucks, 1 traffic light, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 bus, 5 trucks, 1 traffic light, 20.8ms
# Speed: 1.0ms preprocess, 20.8ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 bus, 3 trucks, 1 traffic light, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 3 trucks, 2 traffic lights, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 3 trucks, 2 traffic lights, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 bus, 4 trucks, 1 traffic light, 16.3ms
# Speed: 1.1ms preprocess, 16.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 bus, 3 trucks, 1 traffic light, 15.5ms
# Speed: 1.1ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 4 trucks, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 6 trucks, 1 traffic light, 14.0ms
# Speed: 1.3ms preprocess, 14.0ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 bus, 4 trucks, 1 traffic light, 19.7ms
# Speed: 1.0ms preprocess, 19.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 bus, 3 trucks, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 bus, 2 trucks, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 bus, 2 trucks, 1 traffic light, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 bus, 2 trucks, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 bus, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 10 cars, 1 bus, 1 truck, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 bus, 1 truck, 1 traffic light, 17.9ms
# Speed: 1.0ms preprocess, 17.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 bus, 1 truck, 1 traffic light, 17.0ms
# Speed: 2.5ms preprocess, 17.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 bus, 2 trucks, 1 traffic light, 16.3ms
# Speed: 1.0ms preprocess, 16.3ms inference, 5.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 bus, 2 trucks, 1 traffic light, 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 bus, 1 truck, 1 traffic light, 15.8ms
# Speed: 1.0ms preprocess, 15.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 bus, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 2 buss, 1 truck, 1 traffic light, 14.2ms
# Speed: 1.0ms preprocess, 14.2ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 2 buss, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 2 buss, 1 truck, 2 traffic lights, 16.9ms
# Speed: 1.0ms preprocess, 16.9ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 14 cars, 2 buss, 1 truck, 1 traffic light, 18.5ms
# Speed: 1.1ms preprocess, 18.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 16 cars, 1 bus, 1 truck, 2 traffic lights, 16.9ms
# Speed: 1.0ms preprocess, 16.9ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 bus, 1 truck, 2 traffic lights, 15.1ms
# Speed: 1.1ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 bus, 1 train, 1 truck, 3 traffic lights, 17.2ms
# Speed: 1.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 bus, 1 train, 1 truck, 2 traffic lights, 18.4ms
# Speed: 1.0ms preprocess, 18.4ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 bus, 1 train, 1 truck, 2 traffic lights, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 2 buss, 2 trucks, 2 traffic lights, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 14 cars, 2 buss, 2 trucks, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.3ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 13 cars, 1 truck, 1 traffic light, 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 3 trucks, 2 traffic lights, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 2 trucks, 2 traffic lights, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 2 trucks, 2 traffic lights, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 2 traffic lights, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 2 traffic lights, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 2 trucks, 2 traffic lights, 13.9ms
# Speed: 0.9ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 2 trucks, 2 traffic lights, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 2 trucks, 2 traffic lights, 13.9ms
# Speed: 1.1ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.2ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 traffic light, 13.9ms
# Speed: 0.9ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 1 traffic light, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 1 traffic light, 14.0ms
# Speed: 2.7ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 2 traffic lights, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 1 traffic light, 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 1 truck, 2 traffic lights, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 2 traffic lights, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 2 traffic lights, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 2 traffic lights, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 22 cars, 1 truck, 2 traffic lights, 14.2ms
# Speed: 1.1ms preprocess, 14.2ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 22 cars, 1 truck, 2 traffic lights, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 traffic light, 16.6ms
# Speed: 1.8ms preprocess, 16.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 23 cars, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 21 cars, 1 traffic light, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 2 trucks, 2 traffic lights, 14.0ms
# Speed: 0.9ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 truck, 2 traffic lights, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 3.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.1ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.1ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 1 bus, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 16 cars, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 18 cars, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 18 cars, 1 truck, 1 traffic light, 13.9ms
# Speed: 0.9ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 16 cars, 1 traffic light, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 2.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 15 cars, 1 traffic light, 13.9ms
# Speed: 1.2ms preprocess, 13.9ms inference, 1.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 1 boat, 2 traffic lights, 13.9ms
# Speed: 0.9ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 2 traffic lights, 14.3ms
# Speed: 1.0ms preprocess, 14.3ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 2 trucks, 2 traffic lights, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 truck, 2 traffic lights, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 truck, 2 traffic lights, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 truck, 1 traffic light, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 1 traffic light, 13.6ms
# Speed: 0.9ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 1 traffic light, 13.7ms
# Speed: 1.7ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 2 traffic lights, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 2 traffic lights, 13.6ms
# Speed: 1.2ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 traffic light, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 traffic light, 13.7ms
# Speed: 1.2ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 2 traffic lights, 13.6ms
# Speed: 0.9ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 traffic light, 13.1ms
# Speed: 2.6ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 2 traffic lights, 14.9ms
# Speed: 1.1ms preprocess, 14.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 traffic light, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 traffic light, 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 truck, 1 traffic light, 13.1ms
# Speed: 1.1ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 2 traffic lights, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 traffic light, 13.5ms
# Speed: 1.5ms preprocess, 13.5ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 16.4ms
# Speed: 1.1ms preprocess, 16.4ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 traffic light, 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 traffic light, 13.2ms
# Speed: 1.1ms preprocess, 13.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 stop sign, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 stop sign, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 1 train, 13.1ms
# Speed: 1.1ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 13.2ms
# Speed: 1.1ms preprocess, 13.2ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 1 stop sign, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 stop sign, 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 boat, 1 stop sign, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 stop sign, 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 traffic light, 1 stop sign, 13.1ms
# Speed: 1.1ms preprocess, 13.1ms inference, 1.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 traffic light, 1 stop sign, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 16 cars, 1 stop sign, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 traffic light, 1 stop sign, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 15.4ms
# Speed: 1.0ms preprocess, 15.4ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 13.1ms
# Speed: 1.1ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 1 bus, 1 truck, 1 stop sign, 13.1ms
# Speed: 1.2ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 2 trucks, 1 stop sign, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 1 traffic light, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 3 trucks, 1 traffic light, 13.1ms
# Speed: 0.9ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 traffic light, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 traffic light, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 traffic light, 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 traffic light, 1 stop sign, 14.2ms
# Speed: 1.0ms preprocess, 14.2ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 stop sign, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 1 stop sign, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 1 stop sign, 13.3ms
# Speed: 1.0ms preprocess, 13.3ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 1 stop sign, 14.1ms
# Speed: 2.7ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 truck, 1 traffic light, 1 stop sign, 13.1ms
# Speed: 1.1ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 3 trucks, 1 traffic light, 1 stop sign, 15.7ms
# Speed: 1.4ms preprocess, 15.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 13 cars, 1 bus, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 bus, 1 truck, 1 traffic light, 1 stop sign, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 bus, 2 trucks, 1 traffic light, 1 stop sign, 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 2 trucks, 1 traffic light, 1 stop sign, 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 bus, 1 truck, 1 traffic light, 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 truck, 1 traffic light, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 1 truck, 1 traffic light, 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 19 cars, 1 truck, 1 traffic light, 13.4ms
# Speed: 1.1ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 18 cars, 3 buss, 1 traffic light, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 1 traffic light, 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 traffic light, 13.4ms
# Speed: 1.1ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 traffic light, 13.4ms
# Speed: 0.9ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 traffic light, 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 traffic light, 13.4ms
# Speed: 1.1ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 traffic light, 1 stop sign, 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 traffic light, 1 stop sign, 13.4ms
# Speed: 1.1ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 traffic light, 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 2 traffic lights, 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 traffic light, 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 1.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 truck, 1 traffic light, 13.5ms
# Speed: 1.2ms preprocess, 13.5ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 truck, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 truck, 1 traffic light, 1 stop sign, 13.6ms
# Speed: 1.5ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 truck, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.2ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 truck, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 0.9ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 truck, 1 traffic light, 1 stop sign, 14.4ms
# Speed: 1.0ms preprocess, 14.4ms inference, 2.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 truck, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 11 cars, 1 truck, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 11 cars, 1 truck, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 truck, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 truck, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 11 cars, 1 truck, 1 traffic light, 1 stop sign, 13.9ms
# Speed: 1.2ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 traffic light, 1 stop sign, 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 traffic light, 1 stop sign, 14.1ms
# Speed: 1.3ms preprocess, 14.1ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 truck, 1 traffic light, 1 stop sign, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 traffic light, 1 stop sign, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 traffic light, 1 stop sign, 13.9ms
# Speed: 0.9ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 traffic light, 1 stop sign, 14.4ms
# Speed: 1.0ms preprocess, 14.4ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 12 cars, 1 traffic light, 1 stop sign, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 9 cars, 1 truck, 1 traffic light, 1 stop sign, 13.9ms
# Speed: 1.2ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 10 cars, 1 truck, 1 traffic light, 1 stop sign, 13.9ms
# Speed: 0.9ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 9 cars, 1 truck, 1 traffic light, 1 stop sign, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 9 cars, 1 truck, 1 traffic light, 1 stop sign, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 9 cars, 1 bus, 1 truck, 1 traffic light, 1 stop sign, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 11 cars, 1 bus, 1 traffic light, 1 stop sign, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 11 cars, 1 bus, 1 truck, 1 stop sign, 14.0ms
# Speed: 1.2ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 10 cars, 1 bus, 1 truck, 1 traffic light, 1 stop sign, 14.0ms
# Speed: 1.3ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 11 cars, 1 bus, 1 truck, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 11 cars, 1 bus, 1 truck, 1 traffic light, 14.4ms
# Speed: 1.2ms preprocess, 14.4ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 11 cars, 1 bus, 1 truck, 1 traffic light, 13.7ms
# Speed: 1.1ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 12 cars, 1 bus, 1 truck, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 11 cars, 1 bus, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.1ms preprocess, 13.7ms inference, 2.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 1 bus, 1 traffic light, 1 stop sign, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 11 cars, 1 bus, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 11 cars, 1 bus, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 11 cars, 1 airplane, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.1ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 11 cars, 1 traffic light, 1 stop sign, 13.6ms
# Speed: 0.9ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 13 cars, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.2ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 13 cars, 1 traffic light, 1 stop sign, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 14 cars, 1 truck, 1 traffic light, 1 stop sign, 14.0ms
# Speed: 1.1ms preprocess, 14.0ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 2 trucks, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 truck, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.1ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 traffic light, 1 stop sign, 13.6ms
# Speed: 0.9ms preprocess, 13.6ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 1 bus, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.2ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 1 bus, 1 train, 1 truck, 1 traffic light, 1 stop sign, 13.6ms
# Speed: 1.3ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 2 trucks, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 0.9ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 14 cars, 1 traffic light, 1 stop sign, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.2ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 1 truck, 1 traffic light, 1 stop sign, 13.6ms
# Speed: 1.1ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 21 cars, 1 truck, 1 traffic light, 1 stop sign, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 19 cars, 2 trucks, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 17 cars, 3 trucks, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.7ms preprocess, 13.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 20 cars, 1 bus, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 5.7ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 16 cars, 2 trucks, 1 traffic light, 1 stop sign, 13.7ms
# Speed: 1.2ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 17 cars, 1 truck, 1 stop sign, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 13 cars, 1 truck, 1 stop sign, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 1 person, 16 cars, 1 truck, 1 traffic light, 1 stop sign, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 13 cars, 2 trucks, 1 traffic light, 13.7ms
# Speed: 1.1ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 15 cars, 2 trucks, 1 traffic light, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 2 trucks, 1 traffic light, 13.6ms
# Speed: 0.9ms preprocess, 13.6ms inference, 3.1ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 17 cars, 2 trucks, 1 traffic light, 1 stop sign, 13.6ms
# Speed: 0.9ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 736x1280 16 cars, 2 trucks, 1 traffic light, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.3ms postprocess per image at shape (1, 3, 1280, 1280)

# %%
display.Video(f"{HOME}/result.mp4", height=video_info.height//2, width=video_info.width//2)
# Out:
# <video src="/content/result.mp4" controls  width="640"  height="360">
#       Your browser does not support the <code>video</code> element.
#     </video>
